# %% [markdown]
# ![image.png](attachment:82c8de5d-31c0-499e-b872-5ca3d3487500.png)

# %% [markdown]
# This kernel is going to solve <font color="red"><b> Predict Future Sales with Advanced Regression Analysis</b></font>, a popular machine learning dataset for <b>Kaggler</b>.<br>
# I am going to share how I work with a dataset step by step  <b>from data preparation and data analysis to statistical tests and implementing machine learning models.</b> <br>
# I will also describe the model results along with other tips.<br>
# Let's get started.</div>

# %% [markdown]
# # 1: Importing Necessary Libraries and datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore')

import seaborn as sns
import sys
import itertools
import gc

from sklearn.model_selection import train_test_split
from lightgbm import LGBMRegressor

import csv
from collections import OrderedDict
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

import datetime
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# .datatable .frame thead tr.colnames {  background-image: url('data:image/png;base64,...');  background-repeat: repeat-x;  background-size: 14px;  height: 28px;}
# </style>

# %%
items = pd.read_csv("../input/competitive-data-science-predict-future-sales/items.csv")
shops = pd.read_csv("../input/competitive-data-science-predict-future-sales/shops.csv")
cats = pd.read_csv('../input/competitive-data-science-predict-future-sales/item_categories.csv')
train = pd.read_csv("../input/competitive-data-science-predict-future-sales/sales_train.csv")
test = pd.read_csv("../input/competitive-data-science-predict-future-sales/test.csv")

# %% [markdown]
# # 2. Data Preprocessing

# %%
# Change data type for date calculation
train["date"] = pd.to_datetime(train["date"], format="%d.%m.%Y")
# Merge some duplicate shops
train["shop_id"] = train["shop_id"].replace({0: 57, 1: 58, 11: 10, 40: 39})
# Keep only shops that are in the test set
train = train.loc[train.shop_id.isin(test["shop_id"].unique()), :]
# Drop training items with extreme or negative prices or sales counts
train = train[(train["item_price"] > 0) & (train["item_price"] < 50000)]
train = train[(train["item_cnt_day"] > 0) & (train["item_cnt_day"] < 1000)]

# %%
shops['city'] = shops['shop_name'].apply(lambda x: x.split()[0])
shops.loc[shops['city'] =='!Якутск', 'city'] = 'Якутск'

# Create Label Encoder
label_encoder = LabelEncoder()
# City Feature Label Encoding 
shops['city'] = label_encoder.fit_transform(shops['city'])

# %%
# Create the date the product was first sold as a feature
items['first_sale_date'] = train.groupby('item_id').agg({'date_block_num': 'min'})['date_block_num']
# Refine null values in items table
items = items.apply(lambda x: x.fillna(x.median()) if x.dtype != "O" else x, axis=0)

# %%
cats['split'] = cats['item_category_name'].str.split('-')
cats['type'] = cats['split'].map(lambda x: x[0].strip())
cats['type_code'] = LabelEncoder().fit_transform(cats['type'])
# if subtype is nan then type
cats['subtype'] = cats['split'].map(lambda x: x[1].strip() if len(x) > 1 else x[0].strip())
cats['subtype_code'] = LabelEncoder().fit_transform(cats['subtype'])
cats = cats[['item_category_id','type_code', 'subtype_code']]

# %%
# Merge data
train = train.merge(shops, on='shop_id', how='left')
train = train.merge(items, on='item_id', how='left')
train = train.merge(cats, on='item_category_id', how='left')
test = test.merge(shops, on='shop_id', how='left')
test = test.merge(items, on='item_id', how='left')
test = test.merge(cats, on='item_category_id', how='left')

# %%
test["date_block_num"] = 34
test["date_block_num"] = test["date_block_num"].astype(np.int8)
test["shop_id"] = test.shop_id.astype(np.int8)
test["item_id"] = test.item_id.astype(np.int16)
test = test.drop(columns="ID")

# %%
df = pd.concat([train, test])

# %%
group = train.groupby(['date_block_num','shop_id','item_id']).agg({'item_cnt_day': ['sum']})
group.columns = ['item_cnt_month']
group.reset_index(inplace=True)

df = df.merge(group, on=['date_block_num','shop_id','item_id'], how='left')
df['item_cnt_month'] = (df['item_cnt_month']
                                .fillna(0)
                                .clip(0,20) # NB clip target here
                                .astype(np.float16))

# %%
df = df.drop(['date','shop_name','item_name','item_cnt_day'], axis=1)

# %%
def add_mean(df, idx_features):
    # Check base features
    assert (idx_features[0] == 'date_block_num') and \
           len(idx_features) in [2, 3]
    
    # Set derived feature name 
    if len(idx_features) == 2:
        feature_name = idx_features[1] + '_mean_sales'
    else:
        feature_name = idx_features[1] + '_' + idx_features[2] + '_mean_sales'
    
    # Get average monthly sales by grouping based on base features
    group = df.groupby(idx_features).agg({'item_cnt_month': 'mean'})
    group = group.reset_index()
    group = group.rename(columns={'item_cnt_month': feature_name})
    
    # Merge df with group based on idx_features
    df = df.merge(group, on=idx_features, how='left')
    
    return df

# %%
# Create monthly average sales derived features grouped by ['date_block_num', 'item_id']
df = add_mean(df=df, idx_features=['date_block_num', 'item_id'])

# Create monthly average sales derived features grouped by ['date_block_num', 'shop_id']
df = add_mean(df=df, idx_features=['date_block_num', 'shop_id'])

# Create monthly average sales derived features grouped by ['date_block_num', 'item_category_id']
df = add_mean(df=df, idx_features=['date_block_num', 'item_category_id'])

# Create monthly average sales derived features grouped by ['date_block_num', 'item_id', 'city']
df = add_mean(df=df, idx_features=['date_block_num', 'item_id', 'city'])

# Create monthly average sales derived features grouped by ['date_block_num', 'shop_id', 'item_category_id']
df = add_mean(df=df, idx_features=['date_block_num', 'shop_id', 'item_category_id'])

# Create monthly average sales derived features grouped by ['date_block_num', 'shop_id', 'subtype_code']
df = add_mean(df=df, idx_features=['date_block_num', 'shop_id', 'subtype_code'])

# %%
df['duration_after_first_sale'] = df['date_block_num'] - df['first_sale_date']
df['month'] = df['date_block_num']%12

# %% [markdown]
# # 3. Modeling

# %%
keep_from_month = 2  # The first couple of months are dropped because of distortions to their features (e.g. wrong item age)
valid_month = 33

valid = df.loc[df.date_block_num == valid_month, :]
train = df.loc[df.date_block_num < valid_month, :]
train = train[train.date_block_num >= keep_from_month]
X_train = train.drop(columns="item_cnt_month")
y_train = train.item_cnt_month
X_valid = valid.drop(columns="item_cnt_month")
y_valid = valid.item_cnt_month
test = df.drop(columns="item_cnt_month").loc[df.date_block_num == 34, :]

# %%
model_lgb = LGBMRegressor(colsample_bytree=0.8,learning_rate=0.01, max_depth=8,
              min_child_weight=1, min_split_gain=0.0222415, n_estimators=35000,
              num_leaves=966, reg_alpha=0.04, reg_lambda=0.073,
              subsample=0.6)

# %%
start = datetime.datetime.now()
lgbm = model_lgb.fit(X_train, 
                     y_train,
                     eval_set = [(X_train, y_train), (X_valid, y_valid)],
                     eval_metric ='rmse',
                     early_stopping_rounds = 400,
                     verbose =True)
end = datetime.datetime.now()
end-start
# Out:
# [1]	training's rmse: 5.31147	training's l2: 28.2118	valid_1's rmse: 5.03339	valid_1's l2: 25.335
# [136]	training's rmse: 1.81909	training's l2: 3.30908	valid_1's rmse: 1.72703	valid_1's l2: 2.98263
# [137]	training's rmse: 1.80815	training's l2: 3.2694	valid_1's rmse: 1.71667	valid_1's l2: 2.94695
# [138]	training's rmse: 1.79737	training's l2: 3.23052	valid_1's rmse: 1.70651	valid_1's l2: 2.91217
# [139]	training's rmse: 1.78673	training's l2: 3.19242	valid_1's rmse: 1.69654	valid_1's l2: 2.87826
# [140]	training's rmse: 1.77629	training's l2: 3.1552	valid_1's rmse: 1.68676	valid_1's l2: 2.84517
# [141]	training's rmse: 1.76597	training's l2: 3.11866	valid_1's rmse: 1.67702	valid_1's l2: 2.81239
# [142]	training's rmse: 1.75581	training's l2: 3.08288	valid_1's rmse: 1.66742	valid_1's l2: 2.78028
# [143]	training's rmse: 1.74574	training's l2: 3.0476	valid_1's rmse: 1.65804	valid_1's l2: 2.74908
# [144]	training's rmse: 1.73574	training's l2: 3.01279	valid_1's rmse: 1.6487	valid_1's l2: 2.7182
# [145]	training's rmse: 1.7259	training's l2: 2.97874	valid_1's rmse: 1.63946	valid_1's l2: 2.68783
# [146]	training's rmse: 1.71624	training's l2: 2.94549	valid_1's rmse: 1.63046	valid_1's l2: 2.6584
# [147]	training's rmse: 1.70781	training's l2: 2.91661	valid_1's rmse: 1.62203	valid_1's l2: 2.63097
# [148]	training's rmse: 1.69949	training's l2: 2.88826	valid_1's rmse: 1.61368	valid_1's l2: 2.60396
# [149]	training's rmse: 1.69423	training's l2: 2.87041	valid_1's rmse: 1.60808	valid_1's l2: 2.58591
# [150]	training's rmse: 1.68907	training's l2: 2.85294	valid_1's rmse: 1.60267	valid_1's l2: 2.56855
# [151]	training's rmse: 1.68101	training's l2: 2.8258	valid_1's rmse: 1.59479	valid_1's l2: 2.54335
# [152]	training's rmse: 1.67186	training's l2: 2.79513	valid_1's rmse: 1.58629	valid_1's l2: 2.51632
# [153]	training's rmse: 1.66274	training's l2: 2.76471	valid_1's rmse: 1.5778	valid_1's l2: 2.48946
# [154]	training's rmse: 1.6538	training's l2: 2.73506	valid_1's rmse: 1.56946	valid_1's l2: 2.4632
# [155]	training's rmse: 1.64529	training's l2: 2.70698	valid_1's rmse: 1.56125	valid_1's l2: 2.43751
# [156]	training's rmse: 1.63813	training's l2: 2.68346	valid_1's rmse: 1.55504	valid_1's l2: 2.41816
# [157]	training's rmse: 1.62973	training's l2: 2.65602	valid_1's rmse: 1.54695	valid_1's l2: 2.39305
# [158]	training's rmse: 1.62128	training's l2: 2.62856	valid_1's rmse: 1.53917	valid_1's l2: 2.36903
# [159]	training's rmse: 1.61307	training's l2: 2.602	valid_1's rmse: 1.53158	valid_1's l2: 2.34574
# [160]	training's rmse: 1.60514	training's l2: 2.57648	valid_1's rmse: 1.52405	valid_1's l2: 2.32274
# [161]	training's rmse: 1.59843	training's l2: 2.55499	valid_1's rmse: 1.51833	valid_1's l2: 2.30533
# [162]	training's rmse: 1.59151	training's l2: 2.53289	valid_1's rmse: 1.51146	valid_1's l2: 2.28451
# [243]	training's rmse: 1.2222	training's l2: 1.49378	valid_1's rmse: 1.16449	valid_1's l2: 1.35605
# [244]	training's rmse: 1.22085	training's l2: 1.49048	valid_1's rmse: 1.16295	valid_1's l2: 1.35246
# [245]	training's rmse: 1.21833	training's l2: 1.48433	valid_1's rmse: 1.16076	valid_1's l2: 1.34736
# [246]	training's rmse: 1.21628	training's l2: 1.47934	valid_1's rmse: 1.15869	valid_1's l2: 1.34256
# [247]	training's rmse: 1.21385	training's l2: 1.47344	valid_1's rmse: 1.15658	valid_1's l2: 1.33768
# [248]	training's rmse: 1.21139	training's l2: 1.46747	valid_1's rmse: 1.15433	valid_1's l2: 1.33247
# [249]	training's rmse: 1.20904	training's l2: 1.46177	valid_1's rmse: 1.15222	valid_1's l2: 1.32761
# [250]	training's rmse: 1.20662	training's l2: 1.45592	valid_1's rmse: 1.14993	valid_1's l2: 1.32235
# [251]	training's rmse: 1.20428	training's l2: 1.4503	valid_1's rmse: 1.14763	valid_1's l2: 1.31706
# [252]	training's rmse: 1.20204	training's l2: 1.4449	valid_1's rmse: 1.14548	valid_1's l2: 1.31213
# [253]	training's rmse: 1.19977	training's l2: 1.43945	valid_1's rmse: 1.14327	valid_1's l2: 1.30708
# [254]	training's rmse: 1.19868	training's l2: 1.43684	valid_1's rmse: 1.14208	valid_1's l2: 1.30434
# [255]	training's rmse: 1.1965	training's l2: 1.43162	valid_1's rmse: 1.14	valid_1's l2: 1.29961
# [256]	training's rmse: 1.19474	training's l2: 1.42741	valid_1's rmse: 1.13822	valid_1's l2: 1.29555
# [257]	training's rmse: 1.19256	training's l2: 1.42221	valid_1's rmse: 1.13607	valid_1's l2: 1.29065
# [258]	training's rmse: 1.19051	training's l2: 1.4173	valid_1's rmse: 1.13419	valid_1's l2: 1.2864
# [259]	training's rmse: 1.18845	training's l2: 1.41241	valid_1's rmse: 1.13231	valid_1's l2: 1.28213
# [260]	training's rmse: 1.18633	training's l2: 1.40739	valid_1's rmse: 1.13027	valid_1's l2: 1.27751
# [261]	training's rmse: 1.1847	training's l2: 1.40351	valid_1's rmse: 1.12846	valid_1's l2: 1.27343
# [262]	training's rmse: 1.18264	training's l2: 1.39863	valid_1's rmse: 1.12656	valid_1's l2: 1.26914
# [263]	training's rmse: 1.18058	training's l2: 1.39377	valid_1's rmse: 1.12472	valid_1's l2: 1.265
# [264]	training's rmse: 1.1786	training's l2: 1.38909	valid_1's rmse: 1.12276	valid_1's l2: 1.2606
# [265]	training's rmse: 1.17706	training's l2: 1.38546	valid_1's rmse: 1.12107	valid_1's l2: 1.25679
# [266]	training's rmse: 1.17553	training's l2: 1.38186	valid_1's rmse: 1.11949	valid_1's l2: 1.25327
# [267]	training's rmse: 1.17371	training's l2: 1.3776	valid_1's rmse: 1.11781	valid_1's l2: 1.2495
# [268]	training's rmse: 1.17185	training's l2: 1.37322	valid_1's rmse: 1.11609	valid_1's l2: 1.24565
# [269]	training's rmse: 1.17024	training's l2: 1.36945	valid_1's rmse: 1.11456	valid_1's l2: 1.24225
# [270]	training's rmse: 1.16882	training's l2: 1.36613	valid_1's rmse: 1.11303	valid_1's l2: 1.23884
# [271]	training's rmse: 1.16704	training's l2: 1.36198	valid_1's rmse: 1.1112	valid_1's l2: 1.23476
# [272]	training's rmse: 1.16565	training's l2: 1.35874	valid_1's rmse: 1.10969	valid_1's l2: 1.23142
# [273]	training's rmse: 1.16429	training's l2: 1.35557	valid_1's rmse: 1.10821	valid_1's l2: 1.22813
# [274]	training's rmse: 1.16274	training's l2: 1.35196	valid_1's rmse: 1.10675	valid_1's l2: 1.2249
# [275]	training's rmse: 1.16109	training's l2: 1.34812	valid_1's rmse: 1.10503	valid_1's l2: 1.2211
# [276]	training's rmse: 1.1599	training's l2: 1.34536	valid_1's rmse: 1.10403	valid_1's l2: 1.21888
# [277]	training's rmse: 1.15828	training's l2: 1.34161	valid_1's rmse: 1.10241	valid_1's l2: 1.2153
# [278]	training's rmse: 1.15669	training's l2: 1.33793	valid_1's rmse: 1.10073	valid_1's l2: 1.2116
# [279]	training's rmse: 1.15511	training's l2: 1.33428	valid_1's rmse: 1.09938	valid_1's l2: 1.20864
# [280]	training's rmse: 1.1537	training's l2: 1.33103	valid_1's rmse: 1.09804	valid_1's l2: 1.20568
# [281]	training's rmse: 1.15204	training's l2: 1.32721	valid_1's rmse: 1.09657	valid_1's l2: 1.20246
# [282]	training's rmse: 1.15055	training's l2: 1.32376	valid_1's rmse: 1.09514	valid_1's l2: 1.19934
# [283]	training's rmse: 1.14907	training's l2: 1.32037	valid_1's rmse: 1.09358	valid_1's l2: 1.19592
# [284]	training's rmse: 1.14752	training's l2: 1.3168	valid_1's rmse: 1.09218	valid_1's l2: 1.19286
# [285]	training's rmse: 1.14612	training's l2: 1.31359	valid_1's rmse: 1.09091	valid_1's l2: 1.19008
# [286]	training's rmse: 1.14475	training's l2: 1.31046	valid_1's rmse: 1.08969	valid_1's l2: 1.18742
# [287]	training's rmse: 1.14348	training's l2: 1.30756	valid_1's rmse: 1.08845	valid_1's l2: 1.18472
# [288]	training's rmse: 1.14238	training's l2: 1.30503	valid_1's rmse: 1.0872	valid_1's l2: 1.182
# [289]	training's rmse: 1.14104	training's l2: 1.30196	valid_1's rmse: 1.08591	valid_1's l2: 1.1792
# [290]	training's rmse: 1.14008	training's l2: 1.29979	valid_1's rmse: 1.08456	valid_1's l2: 1.17627
# [291]	training's rmse: 1.13903	training's l2: 1.29739	valid_1's rmse: 1.0835	valid_1's l2: 1.17396
# [292]	training's rmse: 1.13775	training's l2: 1.29448	valid_1's rmse: 1.08228	valid_1's l2: 1.17133
# [293]	training's rmse: 1.13648	training's l2: 1.29159	valid_1's rmse: 1.08104	valid_1's l2: 1.16864
# [294]	training's rmse: 1.13516	training's l2: 1.2886	valid_1's rmse: 1.07982	valid_1's l2: 1.16601
# [295]	training's rmse: 1.13386	training's l2: 1.28565	valid_1's rmse: 1.07861	valid_1's l2: 1.1634
# [296]	training's rmse: 1.13255	training's l2: 1.28268	valid_1's rmse: 1.0774	valid_1's l2: 1.16078
# [297]	training's rmse: 1.13134	training's l2: 1.27994	valid_1's rmse: 1.07619	valid_1's l2: 1.15818
# [298]	training's rmse: 1.13027	training's l2: 1.27751	valid_1's rmse: 1.07504	valid_1's l2: 1.15572
# [299]	training's rmse: 1.12906	training's l2: 1.27477	valid_1's rmse: 1.07375	valid_1's l2: 1.15295
# [300]	training's rmse: 1.12791	training's l2: 1.27219	valid_1's rmse: 1.07274	valid_1's l2: 1.15077
# [301]	training's rmse: 1.12671	training's l2: 1.26947	valid_1's rmse: 1.07154	valid_1's l2: 1.1482
# [302]	training's rmse: 1.1255	training's l2: 1.26674	valid_1's rmse: 1.07042	valid_1's l2: 1.14581
# [303]	training's rmse: 1.12445	training's l2: 1.26439	valid_1's rmse: 1.06943	valid_1's l2: 1.14367
# [304]	training's rmse: 1.12331	training's l2: 1.26183	valid_1's rmse: 1.06827	valid_1's l2: 1.14121
# [305]	training's rmse: 1.1222	training's l2: 1.25933	valid_1's rmse: 1.06722	valid_1's l2: 1.13895
# [306]	training's rmse: 1.12128	training's l2: 1.25726	valid_1's rmse: 1.0663	valid_1's l2: 1.13699
# [307]	training's rmse: 1.12019	training's l2: 1.25483	valid_1's rmse: 1.06518	valid_1's l2: 1.13461
# [308]	training's rmse: 1.11918	training's l2: 1.25257	valid_1's rmse: 1.06428	valid_1's l2: 1.13269
# [309]	training's rmse: 1.1181	training's l2: 1.25014	valid_1's rmse: 1.06324	valid_1's l2: 1.13049
# [310]	training's rmse: 1.11702	training's l2: 1.24774	valid_1's rmse: 1.06236	valid_1's l2: 1.12861
# [311]	training's rmse: 1.11597	training's l2: 1.2454	valid_1's rmse: 1.06136	valid_1's l2: 1.12648
# [312]	training's rmse: 1.11501	training's l2: 1.24325	valid_1's rmse: 1.06061	valid_1's l2: 1.12489
# [313]	training's rmse: 1.1142	training's l2: 1.24145	valid_1's rmse: 1.05984	valid_1's l2: 1.12326
# [314]	training's rmse: 1.11322	training's l2: 1.23927	valid_1's rmse: 1.05879	valid_1's l2: 1.12103
# [315]	training's rmse: 1.11228	training's l2: 1.23717	valid_1's rmse: 1.05781	valid_1's l2: 1.11897
# [316]	training's rmse: 1.11127	training's l2: 1.23492	valid_1's rmse: 1.05689	valid_1's l2: 1.11702
# [317]	training's rmse: 1.1105	training's l2: 1.2332	valid_1's rmse: 1.05619	valid_1's l2: 1.11554
# [318]	training's rmse: 1.10976	training's l2: 1.23158	valid_1's rmse: 1.0554	valid_1's l2: 1.11386
# [319]	training's rmse: 1.10898	training's l2: 1.22984	valid_1's rmse: 1.05458	valid_1's l2: 1.11215
# [320]	training's rmse: 1.10805	training's l2: 1.22778	valid_1's rmse: 1.05374	valid_1's l2: 1.11036
# [321]	training's rmse: 1.10713	training's l2: 1.22573	valid_1's rmse: 1.05279	valid_1's l2: 1.10837
# [322]	training's rmse: 1.10622	training's l2: 1.22372	valid_1's rmse: 1.05186	valid_1's l2: 1.1064
# [323]	training's rmse: 1.10551	training's l2: 1.22215	valid_1's rmse: 1.05107	valid_1's l2: 1.10476
# [324]	training's rmse: 1.10465	training's l2: 1.22026	valid_1's rmse: 1.05029	valid_1's l2: 1.1031
# [325]	training's rmse: 1.10375	training's l2: 1.21826	valid_1's rmse: 1.04941	valid_1's l2: 1.10125
# [326]	training's rmse: 1.10285	training's l2: 1.21628	valid_1's rmse: 1.04851	valid_1's l2: 1.09938
# [327]	training's rmse: 1.10197	training's l2: 1.21433	valid_1's rmse: 1.04763	valid_1's l2: 1.09752
# [328]	training's rmse: 1.10114	training's l2: 1.21252	valid_1's rmse: 1.04682	valid_1's l2: 1.09582
# [329]	training's rmse: 1.10035	training's l2: 1.21078	valid_1's rmse: 1.04606	valid_1's l2: 1.09424
# [330]	training's rmse: 1.09973	training's l2: 1.20942	valid_1's rmse: 1.04537	valid_1's l2: 1.09281
# [331]	training's rmse: 1.09891	training's l2: 1.2076	valid_1's rmse: 1.04457	valid_1's l2: 1.09112
# [332]	training's rmse: 1.09806	training's l2: 1.20574	valid_1's rmse: 1.04388	valid_1's l2: 1.08968
# [333]	training's rmse: 1.09746	training's l2: 1.20442	valid_1's rmse: 1.04318	valid_1's l2: 1.08822
# [334]	training's rmse: 1.09665	training's l2: 1.20264	valid_1's rmse: 1.04229	valid_1's l2: 1.08637
# [335]	training's rmse: 1.09583	training's l2: 1.20085	valid_1's rmse: 1.04152	valid_1's l2: 1.08477
# [336]	training's rmse: 1.09511	training's l2: 1.19926	valid_1's rmse: 1.04077	valid_1's l2: 1.08321
# [337]	training's rmse: 1.09436	training's l2: 1.19763	valid_1's rmse: 1.04001	valid_1's l2: 1.08163
# [338]	training's rmse: 1.09368	training's l2: 1.19613	valid_1's rmse: 1.03945	valid_1's l2: 1.08045
# [339]	training's rmse: 1.09294	training's l2: 1.19451	valid_1's rmse: 1.03873	valid_1's l2: 1.07896
# [340]	training's rmse: 1.09218	training's l2: 1.19287	valid_1's rmse: 1.038	valid_1's l2: 1.07745
# [341]	training's rmse: 1.09152	training's l2: 1.19141	valid_1's rmse: 1.03731	valid_1's l2: 1.07601
# [342]	training's rmse: 1.09084	training's l2: 1.18993	valid_1's rmse: 1.03677	valid_1's l2: 1.07489
# [343]	training's rmse: 1.09015	training's l2: 1.18842	valid_1's rmse: 1.03597	valid_1's l2: 1.07323
# [344]	training's rmse: 1.0895	training's l2: 1.18701	valid_1's rmse: 1.03534	valid_1's l2: 1.07194
# [345]	training's rmse: 1.08886	training's l2: 1.18561	valid_1's rmse: 1.03472	valid_1's l2: 1.07066
# [346]	training's rmse: 1.08818	training's l2: 1.18413	valid_1's rmse: 1.03409	valid_1's l2: 1.06934
# [347]	training's rmse: 1.08767	training's l2: 1.18302	valid_1's rmse: 1.03356	valid_1's l2: 1.06824
# [348]	training's rmse: 1.08702	training's l2: 1.1816	valid_1's rmse: 1.03291	valid_1's l2: 1.06691
# [349]	training's rmse: 1.08642	training's l2: 1.1803	valid_1's rmse: 1.03235	valid_1's l2: 1.06575
# [350]	training's rmse: 1.08595	training's l2: 1.17928	valid_1's rmse: 1.03187	valid_1's l2: 1.06476
# [351]	training's rmse: 1.08534	training's l2: 1.17796	valid_1's rmse: 1.03132	valid_1's l2: 1.06362
# [352]	training's rmse: 1.08476	training's l2: 1.1767	valid_1's rmse: 1.03065	valid_1's l2: 1.06225
# [353]	training's rmse: 1.08433	training's l2: 1.17578	valid_1's rmse: 1.03009	valid_1's l2: 1.06108
# [354]	training's rmse: 1.08372	training's l2: 1.17446	valid_1's rmse: 1.02948	valid_1's l2: 1.05983
# [355]	training's rmse: 1.08313	training's l2: 1.17317	valid_1's rmse: 1.02899	valid_1's l2: 1.05882
# [356]	training's rmse: 1.08255	training's l2: 1.17192	valid_1's rmse: 1.02829	valid_1's l2: 1.05738
# [357]	training's rmse: 1.08203	training's l2: 1.17078	valid_1's rmse: 1.0277	valid_1's l2: 1.05616
# [358]	training's rmse: 1.08143	training's l2: 1.1695	valid_1's rmse: 1.02714	valid_1's l2: 1.05502
# [359]	training's rmse: 1.08106	training's l2: 1.16869	valid_1's rmse: 1.02673	valid_1's l2: 1.05417
# [360]	training's rmse: 1.08052	training's l2: 1.16752	valid_1's rmse: 1.02626	valid_1's l2: 1.05322
# [361]	training's rmse: 1.08008	training's l2: 1.16658	valid_1's rmse: 1.02577	valid_1's l2: 1.05221
# [362]	training's rmse: 1.07962	training's l2: 1.16558	valid_1's rmse: 1.02528	valid_1's l2: 1.05121
# [363]	training's rmse: 1.07916	training's l2: 1.16458	valid_1's rmse: 1.02472	valid_1's l2: 1.05005
# [364]	training's rmse: 1.07865	training's l2: 1.16348	valid_1's rmse: 1.02422	valid_1's l2: 1.04903
# [365]	training's rmse: 1.07825	training's l2: 1.16263	valid_1's rmse: 1.02376	valid_1's l2: 1.04809
# [366]	training's rmse: 1.07785	training's l2: 1.16176	valid_1's rmse: 1.02334	valid_1's l2: 1.04722
# [367]	training's rmse: 1.07726	training's l2: 1.1605	valid_1's rmse: 1.02286	valid_1's l2: 1.04624
# [368]	training's rmse: 1.07686	training's l2: 1.15963	valid_1's rmse: 1.02243	valid_1's l2: 1.04536
# [369]	training's rmse: 1.07634	training's l2: 1.1585	valid_1's rmse: 1.02206	valid_1's l2: 1.04461
# [370]	training's rmse: 1.0759	training's l2: 1.15756	valid_1's rmse: 1.02156	valid_1's l2: 1.04359
# [371]	training's rmse: 1.07548	training's l2: 1.15665	valid_1's rmse: 1.0211	valid_1's l2: 1.04265
# [372]	training's rmse: 1.07496	training's l2: 1.15554	valid_1's rmse: 1.02067	valid_1's l2: 1.04177
# [373]	training's rmse: 1.0745	training's l2: 1.15456	valid_1's rmse: 1.02024	valid_1's l2: 1.04089
# [374]	training's rmse: 1.074	training's l2: 1.15347	valid_1's rmse: 1.01993	valid_1's l2: 1.04026
# [375]	training's rmse: 1.07361	training's l2: 1.15264	valid_1's rmse: 1.01958	valid_1's l2: 1.03954
# [376]	training's rmse: 1.07318	training's l2: 1.15172	valid_1's rmse: 1.01915	valid_1's l2: 1.03867
# [377]	training's rmse: 1.07266	training's l2: 1.1506	valid_1's rmse: 1.01879	valid_1's l2: 1.03792
# [378]	training's rmse: 1.07228	training's l2: 1.14979	valid_1's rmse: 1.01837	valid_1's l2: 1.03708
# [379]	training's rmse: 1.07181	training's l2: 1.14878	valid_1's rmse: 1.01802	valid_1's l2: 1.03637
# [380]	training's rmse: 1.07144	training's l2: 1.14799	valid_1's rmse: 1.01762	valid_1's l2: 1.03555
# [381]	training's rmse: 1.07093	training's l2: 1.14688	valid_1's rmse: 1.01702	valid_1's l2: 1.03433
# [382]	training's rmse: 1.07044	training's l2: 1.14583	valid_1's rmse: 1.0165	valid_1's l2: 1.03327
# [383]	training's rmse: 1.06995	training's l2: 1.1448	valid_1's rmse: 1.01623	valid_1's l2: 1.03273
# [384]	training's rmse: 1.06959	training's l2: 1.14403	valid_1's rmse: 1.01591	valid_1's l2: 1.03207
# [385]	training's rmse: 1.06916	training's l2: 1.1431	valid_1's rmse: 1.01554	valid_1's l2: 1.03131
# [386]	training's rmse: 1.06891	training's l2: 1.14256	valid_1's rmse: 1.01534	valid_1's l2: 1.03092
# [387]	training's rmse: 1.06842	training's l2: 1.14153	valid_1's rmse: 1.01497	valid_1's l2: 1.03017
# [388]	training's rmse: 1.06802	training's l2: 1.14067	valid_1's rmse: 1.01471	valid_1's l2: 1.02963
# [389]	training's rmse: 1.0677	training's l2: 1.13998	valid_1's rmse: 1.01438	valid_1's l2: 1.02898
# [390]	training's rmse: 1.06733	training's l2: 1.1392	valid_1's rmse: 1.014	valid_1's l2: 1.0282
# [391]	training's rmse: 1.067	training's l2: 1.13849	valid_1's rmse: 1.01365	valid_1's l2: 1.02748
# [392]	training's rmse: 1.06656	training's l2: 1.13754	valid_1's rmse: 1.01331	valid_1's l2: 1.0268
# [393]	training's rmse: 1.06624	training's l2: 1.13687	valid_1's rmse: 1.01297	valid_1's l2: 1.0261
# [394]	training's rmse: 1.06586	training's l2: 1.13606	valid_1's rmse: 1.01255	valid_1's l2: 1.02527
# [395]	training's rmse: 1.06544	training's l2: 1.13516	valid_1's rmse: 1.01232	valid_1's l2: 1.0248
# [396]	training's rmse: 1.06516	training's l2: 1.13457	valid_1's rmse: 1.01199	valid_1's l2: 1.02413
# [397]	training's rmse: 1.06477	training's l2: 1.13373	valid_1's rmse: 1.01166	valid_1's l2: 1.02345
# [398]	training's rmse: 1.06446	training's l2: 1.13307	valid_1's rmse: 1.01128	valid_1's l2: 1.02269
# [399]	training's rmse: 1.06413	training's l2: 1.13237	valid_1's rmse: 1.01086	valid_1's l2: 1.02184
# [400]	training's rmse: 1.06373	training's l2: 1.13153	valid_1's rmse: 1.01057	valid_1's l2: 1.02124
# [401]	training's rmse: 1.06336	training's l2: 1.13074	valid_1's rmse: 1.01015	valid_1's l2: 1.02041
# [402]	training's rmse: 1.06306	training's l2: 1.13009	valid_1's rmse: 1.00991	valid_1's l2: 1.01992
# [403]	training's rmse: 1.06271	training's l2: 1.12934	valid_1's rmse: 1.00953	valid_1's l2: 1.01915
# [404]	training's rmse: 1.06232	training's l2: 1.12852	valid_1's rmse: 1.00921	valid_1's l2: 1.0185
# [405]	training's rmse: 1.06188	training's l2: 1.12759	valid_1's rmse: 1.00878	valid_1's l2: 1.01763
# [406]	training's rmse: 1.06157	training's l2: 1.12693	valid_1's rmse: 1.00836	valid_1's l2: 1.01679
# [407]	training's rmse: 1.0613	training's l2: 1.12636	valid_1's rmse: 1.00817	valid_1's l2: 1.0164
# [408]	training's rmse: 1.06109	training's l2: 1.12591	valid_1's rmse: 1.00793	valid_1's l2: 1.01592
# [409]	training's rmse: 1.06074	training's l2: 1.12518	valid_1's rmse: 1.00772	valid_1's l2: 1.0155
# [410]	training's rmse: 1.06049	training's l2: 1.12465	valid_1's rmse: 1.00747	valid_1's l2: 1.01499
# [411]	training's rmse: 1.06025	training's l2: 1.12412	valid_1's rmse: 1.00722	valid_1's l2: 1.01449
# [412]	training's rmse: 1.06	training's l2: 1.1236	valid_1's rmse: 1.00702	valid_1's l2: 1.0141
# [413]	training's rmse: 1.05973	training's l2: 1.12303	valid_1's rmse: 1.0068	valid_1's l2: 1.01364
# [414]	training's rmse: 1.05945	training's l2: 1.12243	valid_1's rmse: 1.0065	valid_1's l2: 1.01303
# [415]	training's rmse: 1.05921	training's l2: 1.12192	valid_1's rmse: 1.00632	valid_1's l2: 1.01267
# [416]	training's rmse: 1.05893	training's l2: 1.12133	valid_1's rmse: 1.00606	valid_1's l2: 1.01217
# [417]	training's rmse: 1.05854	training's l2: 1.12051	valid_1's rmse: 1.00569	valid_1's l2: 1.01141
# [418]	training's rmse: 1.05828	training's l2: 1.11995	valid_1's rmse: 1.00544	valid_1's l2: 1.0109
# [419]	training's rmse: 1.058	training's l2: 1.11937	valid_1's rmse: 1.00522	valid_1's l2: 1.01047
# [420]	training's rmse: 1.05771	training's l2: 1.11875	valid_1's rmse: 1.0049	valid_1's l2: 1.00983
# [421]	training's rmse: 1.05748	training's l2: 1.11826	valid_1's rmse: 1.00471	valid_1's l2: 1.00944
# [422]	training's rmse: 1.05721	training's l2: 1.11769	valid_1's rmse: 1.00446	valid_1's l2: 1.00894
# [423]	training's rmse: 1.05689	training's l2: 1.11701	valid_1's rmse: 1.00411	valid_1's l2: 1.00823
# [424]	training's rmse: 1.05663	training's l2: 1.11646	valid_1's rmse: 1.00391	valid_1's l2: 1.00783
# [425]	training's rmse: 1.05639	training's l2: 1.11595	valid_1's rmse: 1.00369	valid_1's l2: 1.00739
# [426]	training's rmse: 1.05606	training's l2: 1.11527	valid_1's rmse: 1.00333	valid_1's l2: 1.00667
# [427]	training's rmse: 1.05573	training's l2: 1.11457	valid_1's rmse: 1.00309	valid_1's l2: 1.00618
# [428]	training's rmse: 1.05546	training's l2: 1.11401	valid_1's rmse: 1.0028	valid_1's l2: 1.0056
# [429]	training's rmse: 1.05512	training's l2: 1.11329	valid_1's rmse: 1.00247	valid_1's l2: 1.00495
# [430]	training's rmse: 1.05491	training's l2: 1.11285	valid_1's rmse: 1.00224	valid_1's l2: 1.00448
# [431]	training's rmse: 1.05466	training's l2: 1.1123	valid_1's rmse: 1.00194	valid_1's l2: 1.00388
# [432]	training's rmse: 1.05441	training's l2: 1.11179	valid_1's rmse: 1.00158	valid_1's l2: 1.00316
# [433]	training's rmse: 1.05416	training's l2: 1.11124	valid_1's rmse: 1.00133	valid_1's l2: 1.00265
# [434]	training's rmse: 1.05388	training's l2: 1.11066	valid_1's rmse: 1.00107	valid_1's l2: 1.00213
# [435]	training's rmse: 1.05366	training's l2: 1.11019	valid_1's rmse: 1.0009	valid_1's l2: 1.00181
# [436]	training's rmse: 1.05346	training's l2: 1.10979	valid_1's rmse: 1.00068	valid_1's l2: 1.00136
# [437]	training's rmse: 1.0532	training's l2: 1.10924	valid_1's rmse: 1.00047	valid_1's l2: 1.00095
# [438]	training's rmse: 1.05298	training's l2: 1.10876	valid_1's rmse: 1.0003	valid_1's l2: 1.0006
# [439]	training's rmse: 1.05271	training's l2: 1.10821	valid_1's rmse: 0.999964	valid_1's l2: 0.999929
# [440]	training's rmse: 1.05251	training's l2: 1.10777	valid_1's rmse: 0.999721	valid_1's l2: 0.999442
# [441]	training's rmse: 1.05232	training's l2: 1.10739	valid_1's rmse: 0.999512	valid_1's l2: 0.999025
# [442]	training's rmse: 1.05205	training's l2: 1.10681	valid_1's rmse: 0.999209	valid_1's l2: 0.998419
# [443]	training's rmse: 1.05184	training's l2: 1.10636	valid_1's rmse: 0.999	valid_1's l2: 0.998002
# [444]	training's rmse: 1.05164	training's l2: 1.10595	valid_1's rmse: 0.998798	valid_1's l2: 0.997598
# [445]	training's rmse: 1.0515	training's l2: 1.10565	valid_1's rmse: 0.998659	valid_1's l2: 0.997319
# [446]	training's rmse: 1.05125	training's l2: 1.10514	valid_1's rmse: 0.998373	valid_1's l2: 0.996748
# [447]	training's rmse: 1.05106	training's l2: 1.10472	valid_1's rmse: 0.998189	valid_1's l2: 0.996381
# [448]	training's rmse: 1.05078	training's l2: 1.10414	valid_1's rmse: 0.997979	valid_1's l2: 0.995961
# [449]	training's rmse: 1.05056	training's l2: 1.10368	valid_1's rmse: 0.99782	valid_1's l2: 0.995645
# [450]	training's rmse: 1.05038	training's l2: 1.1033	valid_1's rmse: 0.99766	valid_1's l2: 0.995326
# [451]	training's rmse: 1.05014	training's l2: 1.1028	valid_1's rmse: 0.997472	valid_1's l2: 0.99495
# [452]	training's rmse: 1.04998	training's l2: 1.10245	valid_1's rmse: 0.997318	valid_1's l2: 0.994643
# [453]	training's rmse: 1.0498	training's l2: 1.10208	valid_1's rmse: 0.997158	valid_1's l2: 0.994324
# [454]	training's rmse: 1.04955	training's l2: 1.10156	valid_1's rmse: 0.996858	valid_1's l2: 0.993726
# [455]	training's rmse: 1.04929	training's l2: 1.101	valid_1's rmse: 0.996701	valid_1's l2: 0.993413
# [456]	training's rmse: 1.04901	training's l2: 1.10043	valid_1's rmse: 0.996446	valid_1's l2: 0.992905
# [457]	training's rmse: 1.04879	training's l2: 1.09997	valid_1's rmse: 0.996351	valid_1's l2: 0.992714
# [458]	training's rmse: 1.04863	training's l2: 1.09963	valid_1's rmse: 0.996206	valid_1's l2: 0.992425
# [459]	training's rmse: 1.04845	training's l2: 1.09924	valid_1's rmse: 0.996071	valid_1's l2: 0.992157
# [460]	training's rmse: 1.04831	training's l2: 1.09896	valid_1's rmse: 0.995969	valid_1's l2: 0.991954
# [461]	training's rmse: 1.04799	training's l2: 1.09829	valid_1's rmse: 0.995725	valid_1's l2: 0.991468
# [462]	training's rmse: 1.04781	training's l2: 1.09791	valid_1's rmse: 0.995446	valid_1's l2: 0.990913
# [463]	training's rmse: 1.04757	training's l2: 1.0974	valid_1's rmse: 0.995276	valid_1's l2: 0.990574
# [464]	training's rmse: 1.0474	training's l2: 1.09704	valid_1's rmse: 0.99514	valid_1's l2: 0.990303
# [465]	training's rmse: 1.04718	training's l2: 1.0966	valid_1's rmse: 0.994843	valid_1's l2: 0.989713
# [466]	training's rmse: 1.04694	training's l2: 1.09609	valid_1's rmse: 0.994634	valid_1's l2: 0.989297
# [467]	training's rmse: 1.04672	training's l2: 1.09563	valid_1's rmse: 0.994452	valid_1's l2: 0.988935
# [468]	training's rmse: 1.04655	training's l2: 1.09526	valid_1's rmse: 0.994273	valid_1's l2: 0.988579
# [469]	training's rmse: 1.04636	training's l2: 1.09486	valid_1's rmse: 0.994027	valid_1's l2: 0.988089
# [470]	training's rmse: 1.04615	training's l2: 1.09444	valid_1's rmse: 0.99384	valid_1's l2: 0.987719
# [471]	training's rmse: 1.04602	training's l2: 1.09417	valid_1's rmse: 0.993839	valid_1's l2: 0.987715
# [472]	training's rmse: 1.04564	training's l2: 1.09337	valid_1's rmse: 0.993544	valid_1's l2: 0.987129
# [473]	training's rmse: 1.04542	training's l2: 1.09291	valid_1's rmse: 0.993288	valid_1's l2: 0.986622
# [474]	training's rmse: 1.0452	training's l2: 1.09244	valid_1's rmse: 0.993135	valid_1's l2: 0.986317
# [475]	training's rmse: 1.04502	training's l2: 1.09208	valid_1's rmse: 0.99299	valid_1's l2: 0.986029
# [476]	training's rmse: 1.04487	training's l2: 1.09175	valid_1's rmse: 0.992874	valid_1's l2: 0.985799
# [477]	training's rmse: 1.0447	training's l2: 1.0914	valid_1's rmse: 0.992734	valid_1's l2: 0.985521
# [478]	training's rmse: 1.04449	training's l2: 1.09096	valid_1's rmse: 0.992542	valid_1's l2: 0.98514
# [479]	training's rmse: 1.04435	training's l2: 1.09067	valid_1's rmse: 0.992356	valid_1's l2: 0.984771
# [480]	training's rmse: 1.04417	training's l2: 1.0903	valid_1's rmse: 0.99222	valid_1's l2: 0.984501
# [481]	training's rmse: 1.044	training's l2: 1.08993	valid_1's rmse: 0.992052	valid_1's l2: 0.984168
# [482]	training's rmse: 1.04384	training's l2: 1.08959	valid_1's rmse: 0.99187	valid_1's l2: 0.983806
# ...
# [7794]	training's rmse: 0.731306	training's l2: 0.534809	valid_1's rmse: 0.920648	valid_1's l2: 0.847593
# [7795]	training's rmse: 0.731293	training's l2: 0.534789	valid_1's rmse: 0.920646	valid_1's l2: 0.847589
# [7796]	training's rmse: 0.731279	training's l2: 0.53477	valid_1's rmse: 0.920641	valid_1's l2: 0.84758
# [7797]	training's rmse: 0.731257	training's l2: 0.534737	valid_1's rmse: 0.92064	valid_1's l2: 0.847578
# [7798]	training's rmse: 0.731239	training's l2: 0.53471	valid_1's rmse: 0.920644	valid_1's l2: 0.847585
# [7799]	training's rmse: 0.731215	training's l2: 0.534675	valid_1's rmse: 0.920638	valid_1's l2: 0.847575
# [7800]	training's rmse: 0.731208	training's l2: 0.534665	valid_1's rmse: 0.920615	valid_1's l2: 0.847533
# [7801]	training's rmse: 0.731188	training's l2: 0.534636	valid_1's rmse: 0.92063	valid_1's l2: 0.847559
# [7802]	training's rmse: 0.731175	training's l2: 0.534617	valid_1's rmse: 0.920629	valid_1's l2: 0.847558
# [7803]	training's rmse: 0.731165	training's l2: 0.534603	valid_1's rmse: 0.920631	valid_1's l2: 0.847562
# [7804]	training's rmse: 0.731149	training's l2: 0.534578	valid_1's rmse: 0.920634	valid_1's l2: 0.847566
# [7805]	training's rmse: 0.73114	training's l2: 0.534566	valid_1's rmse: 0.920635	valid_1's l2: 0.847569
# [7806]	training's rmse: 0.731122	training's l2: 0.53454	valid_1's rmse: 0.920635	valid_1's l2: 0.847568
# [7807]	training's rmse: 0.731113	training's l2: 0.534526	valid_1's rmse: 0.920624	valid_1's l2: 0.847549
# [7808]	training's rmse: 0.731096	training's l2: 0.534501	valid_1's rmse: 0.920615	valid_1's l2: 0.847532
# [7809]	training's rmse: 0.731081	training's l2: 0.53448	valid_1's rmse: 0.920609	valid_1's l2: 0.84752
# [7810]	training's rmse: 0.731076	training's l2: 0.534472	valid_1's rmse: 0.920599	valid_1's l2: 0.847502
# [7811]	training's rmse: 0.731055	training's l2: 0.534442	valid_1's rmse: 0.92059	valid_1's l2: 0.847486
# [7812]	training's rmse: 0.731042	training's l2: 0.534422	valid_1's rmse: 0.920593	valid_1's l2: 0.847491
# [7813]	training's rmse: 0.731027	training's l2: 0.534401	valid_1's rmse: 0.920606	valid_1's l2: 0.847515
# [7814]	training's rmse: 0.730997	training's l2: 0.534356	valid_1's rmse: 0.920612	valid_1's l2: 0.847527
# [7815]	training's rmse: 0.730994	training's l2: 0.534352	valid_1's rmse: 0.920611	valid_1's l2: 0.847524
# [7816]	training's rmse: 0.730982	training's l2: 0.534334	valid_1's rmse: 0.920609	valid_1's l2: 0.847522
# [7817]	training's rmse: 0.730956	training's l2: 0.534297	valid_1's rmse: 0.920622	valid_1's l2: 0.847544
# [7818]	training's rmse: 0.730918	training's l2: 0.534241	valid_1's rmse: 0.920615	valid_1's l2: 0.847533
# [7819]	training's rmse: 0.730896	training's l2: 0.534208	valid_1's rmse: 0.920618	valid_1's l2: 0.847538
# [7820]	training's rmse: 0.730882	training's l2: 0.534189	valid_1's rmse: 0.920611	valid_1's l2: 0.847525
# [7821]	training's rmse: 0.730866	training's l2: 0.534164	valid_1's rmse: 0.920608	valid_1's l2: 0.847519
# [7822]	training's rmse: 0.730851	training's l2: 0.534144	valid_1's rmse: 0.920594	valid_1's l2: 0.847493
# [7823]	training's rmse: 0.730828	training's l2: 0.534109	valid_1's rmse: 0.920596	valid_1's l2: 0.847497
# [7824]	training's rmse: 0.730795	training's l2: 0.534061	valid_1's rmse: 0.920585	valid_1's l2: 0.847477
# [7825]	training's rmse: 0.730783	training's l2: 0.534044	valid_1's rmse: 0.920587	valid_1's l2: 0.847481
# [7826]	training's rmse: 0.730757	training's l2: 0.534006	valid_1's rmse: 0.92058	valid_1's l2: 0.847467
# [7827]	training's rmse: 0.730753	training's l2: 0.534001	valid_1's rmse: 0.920577	valid_1's l2: 0.847462
# [7828]	training's rmse: 0.73072	training's l2: 0.533952	valid_1's rmse: 0.920587	valid_1's l2: 0.84748
# [7829]	training's rmse: 0.7307	training's l2: 0.533923	valid_1's rmse: 0.920593	valid_1's l2: 0.847491
# [7830]	training's rmse: 0.730673	training's l2: 0.533883	valid_1's rmse: 0.920594	valid_1's l2: 0.847494
# [7831]	training's rmse: 0.730641	training's l2: 0.533836	valid_1's rmse: 0.920574	valid_1's l2: 0.847457
# [7832]	training's rmse: 0.730617	training's l2: 0.533802	valid_1's rmse: 0.920594	valid_1's l2: 0.847493
# [7833]	training's rmse: 0.730597	training's l2: 0.533773	valid_1's rmse: 0.920597	valid_1's l2: 0.847498
# [7834]	training's rmse: 0.730579	training's l2: 0.533746	valid_1's rmse: 0.920605	valid_1's l2: 0.847513
# [7835]	training's rmse: 0.730519	training's l2: 0.533659	valid_1's rmse: 0.920603	valid_1's l2: 0.84751
# [7836]	training's rmse: 0.730507	training's l2: 0.533641	valid_1's rmse: 0.920627	valid_1's l2: 0.847553
# [7837]	training's rmse: 0.730461	training's l2: 0.533573	valid_1's rmse: 0.920632	valid_1's l2: 0.847563
# [7838]	training's rmse: 0.730438	training's l2: 0.53354	valid_1's rmse: 0.920641	valid_1's l2: 0.84758
# [7839]	training's rmse: 0.730409	training's l2: 0.533498	valid_1's rmse: 0.920645	valid_1's l2: 0.847587
# [7840]	training's rmse: 0.730385	training's l2: 0.533463	valid_1's rmse: 0.920659	valid_1's l2: 0.847613
# [7841]	training's rmse: 0.730364	training's l2: 0.533432	valid_1's rmse: 0.920669	valid_1's l2: 0.847632
# [7842]	training's rmse: 0.730342	training's l2: 0.5334	valid_1's rmse: 0.920673	valid_1's l2: 0.847639
# [7843]	training's rmse: 0.730324	training's l2: 0.533372	valid_1's rmse: 0.920679	valid_1's l2: 0.847649
# [7844]	training's rmse: 0.730305	training's l2: 0.533345	valid_1's rmse: 0.920676	valid_1's l2: 0.847645
# [7845]	training's rmse: 0.730269	training's l2: 0.533293	valid_1's rmse: 0.920675	valid_1's l2: 0.847643
# [7846]	training's rmse: 0.73025	training's l2: 0.533265	valid_1's rmse: 0.920685	valid_1's l2: 0.847661
# [7847]	training's rmse: 0.730246	training's l2: 0.533259	valid_1's rmse: 0.920684	valid_1's l2: 0.847659
# [7848]	training's rmse: 0.730219	training's l2: 0.53322	valid_1's rmse: 0.92069	valid_1's l2: 0.84767
# [7849]	training's rmse: 0.73019	training's l2: 0.533177	valid_1's rmse: 0.920685	valid_1's l2: 0.847662
# [7850]	training's rmse: 0.730159	training's l2: 0.533132	valid_1's rmse: 0.920689	valid_1's l2: 0.847668
# [7851]	training's rmse: 0.73014	training's l2: 0.533105	valid_1's rmse: 0.920695	valid_1's l2: 0.84768
# [7852]	training's rmse: 0.730126	training's l2: 0.533083	valid_1's rmse: 0.920698	valid_1's l2: 0.847685
# [7853]	training's rmse: 0.730117	training's l2: 0.53307	valid_1's rmse: 0.920695	valid_1's l2: 0.84768
# [7854]	training's rmse: 0.730112	training's l2: 0.533063	valid_1's rmse: 0.920693	valid_1's l2: 0.847676
# [7855]	training's rmse: 0.730103	training's l2: 0.53305	valid_1's rmse: 0.920697	valid_1's l2: 0.847683
# [7856]	training's rmse: 0.73007	training's l2: 0.533002	valid_1's rmse: 0.920701	valid_1's l2: 0.847691
# [7857]	training's rmse: 0.730063	training's l2: 0.532991	valid_1's rmse: 0.920708	valid_1's l2: 0.847702
# [7858]	training's rmse: 0.730036	training's l2: 0.532953	valid_1's rmse: 0.9207	valid_1's l2: 0.847688
# [7859]	training's rmse: 0.730028	training's l2: 0.532942	valid_1's rmse: 0.920688	valid_1's l2: 0.847667
# [7860]	training's rmse: 0.730021	training's l2: 0.532931	valid_1's rmse: 0.920685	valid_1's l2: 0.847661
# [7861]	training's rmse: 0.730013	training's l2: 0.532919	valid_1's rmse: 0.920681	valid_1's l2: 0.847653
# [7862]	training's rmse: 0.729973	training's l2: 0.532861	valid_1's rmse: 0.920678	valid_1's l2: 0.847647
# [7863]	training's rmse: 0.729949	training's l2: 0.532825	valid_1's rmse: 0.920682	valid_1's l2: 0.847655
# [7864]	training's rmse: 0.729941	training's l2: 0.532814	valid_1's rmse: 0.920679	valid_1's l2: 0.84765
# [7865]	training's rmse: 0.729932	training's l2: 0.5328	valid_1's rmse: 0.920679	valid_1's l2: 0.84765
# [7866]	training's rmse: 0.729927	training's l2: 0.532793	valid_1's rmse: 0.920682	valid_1's l2: 0.847655
# [7867]	training's rmse: 0.729913	training's l2: 0.532772	valid_1's rmse: 0.92066	valid_1's l2: 0.847615
# [7868]	training's rmse: 0.729907	training's l2: 0.532765	valid_1's rmse: 0.920651	valid_1's l2: 0.847598
# [7869]	training's rmse: 0.729868	training's l2: 0.532707	valid_1's rmse: 0.920664	valid_1's l2: 0.847622
# [7870]	training's rmse: 0.729852	training's l2: 0.532684	valid_1's rmse: 0.920664	valid_1's l2: 0.847622
# [7871]	training's rmse: 0.72981	training's l2: 0.532622	valid_1's rmse: 0.92067	valid_1's l2: 0.847634
# [7872]	training's rmse: 0.729786	training's l2: 0.532587	valid_1's rmse: 0.92067	valid_1's l2: 0.847633
# [7873]	training's rmse: 0.729774	training's l2: 0.53257	valid_1's rmse: 0.920666	valid_1's l2: 0.847626
# [7874]	training's rmse: 0.729769	training's l2: 0.532563	valid_1's rmse: 0.92066	valid_1's l2: 0.847615
# [7875]	training's rmse: 0.729765	training's l2: 0.532556	valid_1's rmse: 0.920653	valid_1's l2: 0.847601
# [7876]	training's rmse: 0.729733	training's l2: 0.53251	valid_1's rmse: 0.920644	valid_1's l2: 0.847586
# [7877]	training's rmse: 0.729725	training's l2: 0.532498	valid_1's rmse: 0.920647	valid_1's l2: 0.847592
# [7878]	training's rmse: 0.729709	training's l2: 0.532476	valid_1's rmse: 0.920647	valid_1's l2: 0.847591
# [7879]	training's rmse: 0.729699	training's l2: 0.53246	valid_1's rmse: 0.920659	valid_1's l2: 0.847613
# [7880]	training's rmse: 0.729693	training's l2: 0.532451	valid_1's rmse: 0.920652	valid_1's l2: 0.8476
# [7881]	training's rmse: 0.729677	training's l2: 0.532428	valid_1's rmse: 0.920649	valid_1's l2: 0.847594
# [7882]	training's rmse: 0.729669	training's l2: 0.532417	valid_1's rmse: 0.920621	valid_1's l2: 0.847543
# [7883]	training's rmse: 0.729654	training's l2: 0.532395	valid_1's rmse: 0.920642	valid_1's l2: 0.847581
# [7884]	training's rmse: 0.729634	training's l2: 0.532366	valid_1's rmse: 0.920602	valid_1's l2: 0.847509
# [7885]	training's rmse: 0.729624	training's l2: 0.532352	valid_1's rmse: 0.920601	valid_1's l2: 0.847506
# [7886]	training's rmse: 0.729603	training's l2: 0.532321	valid_1's rmse: 0.920604	valid_1's l2: 0.847512
# [7887]	training's rmse: 0.729585	training's l2: 0.532295	valid_1's rmse: 0.920598	valid_1's l2: 0.8475
# [7888]	training's rmse: 0.729557	training's l2: 0.532254	valid_1's rmse: 0.920591	valid_1's l2: 0.847487
# [7889]	training's rmse: 0.72955	training's l2: 0.532242	valid_1's rmse: 0.92059	valid_1's l2: 0.847486
# [7890]	training's rmse: 0.729542	training's l2: 0.532231	valid_1's rmse: 0.920589	valid_1's l2: 0.847485
# [7891]	training's rmse: 0.729535	training's l2: 0.532222	valid_1's rmse: 0.92059	valid_1's l2: 0.847485
# [7892]	training's rmse: 0.729522	training's l2: 0.532203	valid_1's rmse: 0.920596	valid_1's l2: 0.847496
# [7893]	training's rmse: 0.729513	training's l2: 0.532189	valid_1's rmse: 0.9206	valid_1's l2: 0.847504
# [7894]	training's rmse: 0.729487	training's l2: 0.532152	valid_1's rmse: 0.920611	valid_1's l2: 0.847524
# [7895]	training's rmse: 0.729485	training's l2: 0.532148	valid_1's rmse: 0.920607	valid_1's l2: 0.847517
# [7896]	training's rmse: 0.729472	training's l2: 0.532129	valid_1's rmse: 0.920606	valid_1's l2: 0.847515
# [7897]	training's rmse: 0.729457	training's l2: 0.532108	valid_1's rmse: 0.920616	valid_1's l2: 0.847534
# [7898]	training's rmse: 0.729434	training's l2: 0.532075	valid_1's rmse: 0.920644	valid_1's l2: 0.847585
# [7899]	training's rmse: 0.72943	training's l2: 0.532068	valid_1's rmse: 0.920634	valid_1's l2: 0.847567
# [7900]	training's rmse: 0.729421	training's l2: 0.532055	valid_1's rmse: 0.920637	valid_1's l2: 0.847573
# [7901]	training's rmse: 0.729402	training's l2: 0.532027	valid_1's rmse: 0.920627	valid_1's l2: 0.847555
# [7902]	training's rmse: 0.72939	training's l2: 0.53201	valid_1's rmse: 0.920629	valid_1's l2: 0.847559
# [7903]	training's rmse: 0.729358	training's l2: 0.531964	valid_1's rmse: 0.920592	valid_1's l2: 0.84749
# [7904]	training's rmse: 0.729329	training's l2: 0.531921	valid_1's rmse: 0.920582	valid_1's l2: 0.847471
# [7905]	training's rmse: 0.729323	training's l2: 0.531912	valid_1's rmse: 0.920581	valid_1's l2: 0.84747
# [7906]	training's rmse: 0.729306	training's l2: 0.531888	valid_1's rmse: 0.920585	valid_1's l2: 0.847476
# [7907]	training's rmse: 0.729299	training's l2: 0.531878	valid_1's rmse: 0.92058	valid_1's l2: 0.847468
# [7908]	training's rmse: 0.729281	training's l2: 0.53185	valid_1's rmse: 0.920594	valid_1's l2: 0.847493
# [7909]	training's rmse: 0.729244	training's l2: 0.531797	valid_1's rmse: 0.920601	valid_1's l2: 0.847507
# [7910]	training's rmse: 0.729228	training's l2: 0.531773	valid_1's rmse: 0.920604	valid_1's l2: 0.847511
# [7911]	training's rmse: 0.729221	training's l2: 0.531763	valid_1's rmse: 0.920605	valid_1's l2: 0.847513
# [7912]	training's rmse: 0.729217	training's l2: 0.531757	valid_1's rmse: 0.920599	valid_1's l2: 0.847503
# [7913]	training's rmse: 0.729186	training's l2: 0.531712	valid_1's rmse: 0.920596	valid_1's l2: 0.847497
# [7914]	training's rmse: 0.72916	training's l2: 0.531674	valid_1's rmse: 0.920579	valid_1's l2: 0.847465
# [7915]	training's rmse: 0.729142	training's l2: 0.531648	valid_1's rmse: 0.920579	valid_1's l2: 0.847466
# [7916]	training's rmse: 0.72912	training's l2: 0.531615	valid_1's rmse: 0.92057	valid_1's l2: 0.847449
# [7917]	training's rmse: 0.729106	training's l2: 0.531595	valid_1's rmse: 0.920579	valid_1's l2: 0.847466
# [7918]	training's rmse: 0.729088	training's l2: 0.53157	valid_1's rmse: 0.920609	valid_1's l2: 0.84752
# [7919]	training's rmse: 0.729083	training's l2: 0.531561	valid_1's rmse: 0.920599	valid_1's l2: 0.847502
# [7920]	training's rmse: 0.72905	training's l2: 0.531514	valid_1's rmse: 0.920592	valid_1's l2: 0.84749
# [7921]	training's rmse: 0.729047	training's l2: 0.53151	valid_1's rmse: 0.920592	valid_1's l2: 0.847489
# [7922]	training's rmse: 0.728996	training's l2: 0.531435	valid_1's rmse: 0.92057	valid_1's l2: 0.847449
# [7923]	training's rmse: 0.72896	training's l2: 0.531383	valid_1's rmse: 0.920554	valid_1's l2: 0.847419
# [7924]	training's rmse: 0.728953	training's l2: 0.531373	valid_1's rmse: 0.920553	valid_1's l2: 0.847418
# [7925]	training's rmse: 0.728945	training's l2: 0.531361	valid_1's rmse: 0.920551	valid_1's l2: 0.847414
# [7926]	training's rmse: 0.728939	training's l2: 0.531353	valid_1's rmse: 0.920553	valid_1's l2: 0.847418
# [7927]	training's rmse: 0.72893	training's l2: 0.531339	valid_1's rmse: 0.920551	valid_1's l2: 0.847414
# [7928]	training's rmse: 0.728924	training's l2: 0.53133	valid_1's rmse: 0.920551	valid_1's l2: 0.847415
# [7929]	training's rmse: 0.728914	training's l2: 0.531316	valid_1's rmse: 0.920545	valid_1's l2: 0.847403
# [7930]	training's rmse: 0.728905	training's l2: 0.531303	valid_1's rmse: 0.920542	valid_1's l2: 0.847397
# [7931]	training's rmse: 0.728902	training's l2: 0.531298	valid_1's rmse: 0.920541	valid_1's l2: 0.847396
# [7932]	training's rmse: 0.728893	training's l2: 0.531285	valid_1's rmse: 0.920538	valid_1's l2: 0.847391
# [7933]	training's rmse: 0.728887	training's l2: 0.531276	valid_1's rmse: 0.920536	valid_1's l2: 0.847386
# [7934]	training's rmse: 0.728871	training's l2: 0.531253	valid_1's rmse: 0.920533	valid_1's l2: 0.847381
# [7935]	training's rmse: 0.728837	training's l2: 0.531203	valid_1's rmse: 0.920549	valid_1's l2: 0.847411
# [7936]	training's rmse: 0.728824	training's l2: 0.531184	valid_1's rmse: 0.920553	valid_1's l2: 0.847419
# [7937]	training's rmse: 0.728817	training's l2: 0.531174	valid_1's rmse: 0.920554	valid_1's l2: 0.847419
# [7938]	training's rmse: 0.728783	training's l2: 0.531125	valid_1's rmse: 0.920538	valid_1's l2: 0.84739
# [7939]	training's rmse: 0.728773	training's l2: 0.53111	valid_1's rmse: 0.920531	valid_1's l2: 0.847376
# [7940]	training's rmse: 0.728741	training's l2: 0.531063	valid_1's rmse: 0.920505	valid_1's l2: 0.847329
# [7941]	training's rmse: 0.72873	training's l2: 0.531047	valid_1's rmse: 0.920512	valid_1's l2: 0.847342
# [7942]	training's rmse: 0.728714	training's l2: 0.531024	valid_1's rmse: 0.920507	valid_1's l2: 0.847334
# [7943]	training's rmse: 0.728706	training's l2: 0.531012	valid_1's rmse: 0.920502	valid_1's l2: 0.847325
# [7944]	training's rmse: 0.728693	training's l2: 0.530994	valid_1's rmse: 0.920509	valid_1's l2: 0.847336
# [7945]	training's rmse: 0.728662	training's l2: 0.530949	valid_1's rmse: 0.920509	valid_1's l2: 0.847337
# datetime.timedelta(seconds=785, microseconds=928696)

# %%
feature_imp= pd.DataFrame(sorted(zip(lgbm.feature_importances_, X_train.columns), reverse = True), columns = ['Value', 'Feature'])
# feature_imp.to_excel("feature_imp.xlsx")

plt.figure(figsize=(7,5))
sns.barplot(x='Value', y='Feature', data=feature_imp[:10].sort_values(by='Value', ascending=False))
plt.tight_layout()
plt.show()
# plt.savefig('lightGBM_ Importances.png')

# %%
sales_prediction = model_lgb.predict(test)
test = pd.read_csv("../input/competitive-data-science-predict-future-sales/test.csv")
test_result= pd.DataFrame(sales_prediction)
test_result.columns = ['item_cnt_month']
predict = test_result['item_cnt_month']
sales_predict_submission = pd.DataFrame({'ID':test['ID'],'item_cnt_month':predict})
sales_predict_submission.to_csv('submission.csv', index=False)
